# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Colab Notebooks/SA-project
# Out:
# /content/drive/MyDrive/Colab Notebooks/SA-project

# %%
# Out:
# Cloning into 'SA-project'...
# ...

# %%
# !git config --global user.email 'shjj9250@gmail.com'
# !git config --global user.name '허준재'

# %%
# !git add .

# !git commit -m 'first commit'

# !git push -u origin main
# Out:
# [main (root-commit) a536054] first commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 "\341\204\211\341\205\251\341\204\221\341\205\263\341\204\220\341\205\263\341\204\213\341\205\260\341\204\213\341\205\245\341\204\213\341\205\263\341\206\274\341\204\213\341\205\255\341\206\2741.ipynb"
# fatal: could not read Username for 'https://github.com': No such device or address
